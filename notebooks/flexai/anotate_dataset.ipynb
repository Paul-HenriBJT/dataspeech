# %% [markdown]
# ##The goal of this notebook is to anotate a dataset using Flex AI cloud service

# %%
# !flexai doctor
# Out:
# Running doctor checks...
# [1/3] ✅ BinaryInPath
# [2/3] ✅ BackendServer
# [3/3] ✅ UpdateServer
# Your system is healthy

# %%
# Install required packages
!%pip install datasets

# Download the dataset
from datasets import load_dataset
dataset = load_dataset("ylacombe/jenny-tts-6h")

# Save the dataset files locally
dataset.save_to_disk("jenny-tts-6h")
# Out:
# zsh:fg:1: no job control in this shell.
# Saving the dataset (0/3 shards):   0%|          | 0/4000 [00:00<?, ? examples/s]

# %%
# Upload the dataset to GitHub using Flexai
# !flexai dataset push "jenny-tts-6h-04" \
    -f "data/train-00000-of-00003.arrow"="dataspeech/notebooks/jenny-tts-6h/train/data-00000-of-00003.arrow" \
    -f "data/train-00001-of-00003.arrow"="dataspeech/notebooks/jenny-tts-6h/train/data-00001-of-00003.arrow" \
    -f "data/train-00002-of-00003.arrow"="dataspeech/notebooks/jenny-tts-6h/train/data-00002-of-00003.arrow"
# Out:
# Create a new dataset
#
#  File: data-00000-of-00003.arrow
#  [1/3] Read file metadata        In progress
#  [2/3] Calculate checksum        Not started
#  [3/3] Upload file               Not started
#
#  File: data-00001-of-00003.arrow
#  [1/3] Read file metadata        Not started
#  [2/3] Calculate checksum        Not started
#  [3/3] Upload file               Not started
#
#  File: data-00002-of-00003.arrow
#  [1/3] Read file metadata        Not started
#  [2/3] Calculate checksum        Not started
#  [3/3] Upload file               Not started
#
#  File: data-00000-of-00003.arrow
#  [1/3] Read file metadata        Complete
#  [2/3] Calculate checksum        Not started
#  [3/3] Upload file               Not started
#
#  File: data-00001-of-00003.arrow
#  [1/3] Read file metadata        Not started
#  [2/3] Calculate checksum        Not started
#  [3/3] Upload file               Not started
#
#  File: data-00002-of-00003.arrow
#  [1/3] Read file metadata        Not started
# ...

# %%
# !flexai source add dataspeech-source https://github.com/Paul-HenriBJT/dataspeech.git
# Out:
# Source dataspeech-source added successfully

# %%
# !flexai training run \
    mls_annotation_german_0001 \
    --source-name dataspeech-source \
    --source-revision cleaned-german \
    --dataset nano-gpt-tutorial-dataset \
    --accels 2 \
    -- main.py "facebook/multilingual_librispeech"\
        --configuration "french" \
        --output_dir "/output/mls_french" \
        --text_column_name "transcript" \
        --audio_column_name "audio" \
        --repo_id "PHBJT/multilingual_librispeech" \
        --hub_token "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" \
        --cpu_num_workers 8 \
        --rename_column \
        --apply_squim_quality_estimation
# Out:
# Training mls_annotation_french_0001 started

# %%
nohup python main.py "ylacombe/cml-tts" \
    --configuration french \
    --text_column_name text \
    --audio_column_name audio \
    --output_dir="/output" \
    --batch_size 128 \
    --penn_batch_size 16384 \
    --num_workers_per_gpu_for_pitch 8 \
    --num_workers_per_gpu_for_snr 8 \
    --num_workers_per_gpu_for_squim 8 \
    --apply_squim_quality_estimation \
    --cpu_num_workers 64 \
    --cpu_writer_batch_size 10000 \
    --repo_id  "PHBJT/french-cml-tts-tagged" \
    > python_script_output.log 2>&1 &


nohup python main.py "PHBJT/cml-tts-5percent-subset" \
    --text_column_name "text" \
    --audio_column_name "audio" \
    --cpu_num_workers 8 \
    --rename_column \
    --repo_id  "PHBJT/cml-tts-5percent-subset-tagged" \
    --apply_squim_quality_estimation \
    > python_script_output.log 2>&1 &

python

# %%
flexai training run
